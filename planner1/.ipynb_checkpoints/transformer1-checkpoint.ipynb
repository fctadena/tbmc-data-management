# %%
import pandas as pd

# %%
file_path = 'Project Timeline Update.xlsx'

# %%
def transformer1(file_path):
    data = pd.read_excel(file_path)
    return data

# %%
data = transformer1(file_path)

# %%
data
# Out:
#                           Task ID  \
# 0    S8APNAURRkSjyCQvPPYzZJYAF0E2
# 1    uL0kePJnRkSQRQOhlh2lW5YAHH2W
# 2    hXT-cXwd7UW2qtrnkCXM05YAGSQ6
# 3    ftatfYwW7U2-sGlBPakr-5YANNT7
# 4    UwM4R4m6EUywuHZupaUUTpYACvjC
# ..                            ...
# 118  jNxYFUpwqkW4ZNFodzhwCJYAMPNi
# 119  -HSgex3d-keTvOed7xmNwpYAKIRR
# 120  reioAKbv30SXFL0HQ2agXJYAKBDc
# 121  tFIFAIiyqEu3fR_o3TvGfpYAFoTw
# 122  IehKXb2I60u1q3cudI3wjZYAIz6u
#
#                                              Task Name  \
# 0    Fully signed URS of Relief Valve and CIP pump ...
# 1       URS of Relief Valve and CIP pump for new scope
# 2                               Pre-bidding of Group 4
# 3                              Pre-bidding of Group 3
# 4                               Pre-bidding of Group 2
# ..                                                 ...
# 118                                      Create a Plan
# 119      Fully Signed Design Freeze for Dust Collector
# 120                                 Customize  buckets
# 121                Add additional information to tasks
# 122              Delivery of additional control cables
#
#                            Bucket Name     Progress Priority  \
# 0    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 1    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 2    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 3    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 4    PEC2020 - (EA) Process Adaptation  Not started   Medium
# ..                                 ...          ...      ...
# 118     E54 High Pressure Water Heater  Not started   Medium
# 119                   GC Transport PH2  Not started   Medium
# 120                           FFE RARE  Not started   Medium
# 121                        Van Tilting  Not started   Medium
# 122  PEC2020 - PE Panel cooling system    Completed   Medium
#
#                                            Assigned To  \
# 0    Suello,Rosiell,PH-Cagayan de Oro,Engineering,E...
# 1    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# 2    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# 3    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# 4    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# ..                                                 ...
# 118                                                NaN
# 119  Suello,Rosiell,PH-Cagayan de Oro,Engineering,E...
# 120                                                NaN
# 121                                                NaN
# 122  Pacatan,Arnold,PH-Cagayan de Oro,Engineering,E...
#
#                                             Created By Created Date  \
# 0    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 1    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 2    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 3    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 4    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# ..                                                 ...          ...
# 118  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 119  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 120  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 121  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 122  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
#
#     Start date    Due date  Is Recurring   Late Completed Date  \
# 0          NaN  07/19/2024         False  False            NaN
# 1          NaN  07/12/2024         False  False            NaN
# 2          NaN  02/14/2025         False  False            NaN
# 3          NaN  08/30/2024         False  False            NaN
# 4          NaN  07/05/2024         False  False            NaN
# ..         ...         ...           ...    ...            ...
# 118        NaN  06/26/2024         False   True            NaN
# 119        NaN  07/12/2024         False  False            NaN
# 120        NaN  07/02/2024         False   True            NaN
# 121        NaN  07/11/2024         False  False            NaN
# 122        NaN  05/30/2025         False  False     07/02/2024
#
#                                           Completed By  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122  Pacatan,Arnold,PH-Cagayan de Oro,Engineering,E...
#
#     Completed Checklist Items  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 118                       NaN
# 119                       NaN
# 120                       NaN
# 121                       0/7
# 122                       NaN
#
#                                        Checklist Items      Labels  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 118                                                NaN         NaN
# 119                                                NaN         NaN
# 120                                                NaN  Pink;Green
# 121  Add duration;Add attachments;Add labels;Add ef...         NaN
# 122                                                NaN         NaN
#
#                                            Description
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 118       Create a plan using the simple plan template
# 119           Assign tasks to yourself or team members
# 120  Edit the names of buckets in the project to fi...
# 121                                                NaN
# 122                                                NaN
#
# [123 rows x 18 columns]

# %%
# Loop through the 'Assigned To' column with index
for idx, i in enumerate(data['Assigned To']):
    assigned_list = str(i).split(';')
    if len(assigned_list) > 1:
        print(f'Index:{idx}')
        row_values = data.loc[idx].values #Getting the values of the row
# Out:
# Index:2
# Index:3
# Index:4
# Index:5
# Index:6
# Index:7
# Index:9
# Index:11
# Index:13
# Index:15
# Index:17
# Index:29
# Index:30
# Index:31
# Index:32
# Index:33
# Index:49
# Index:50
# Index:51
# Index:66
# Index:67
# Index:68
# Index:69
# Index:70
# Index:81
# Index:82
# Index:83
# Index:84
# Index:85
# Index:86
# Index:88
# Index:96
# Index:97
# Index:98
# Index:99
# Index:100
# Index:101
# Index:102
# Index:103
# Index:104
# Index:105
# Index:106
# Index:107
# Index:108
# Index:109
# Index:110
# Index:111

# %%
new_row = pd.DataFrame([['IehKXb2I60u1q3cudI3wjZYAIz6uzzzzzzz', 'Delivery of additional control cables2']], columns=['Task ID', 'Task Name'])
data.loc[124:] = pd.concat([data.loc[124:], new_row]).reset_index(drop=True)

# %%
data
# Out:
#                           Task ID  \
# 0    S8APNAURRkSjyCQvPPYzZJYAF0E2
# 1    uL0kePJnRkSQRQOhlh2lW5YAHH2W
# 2    hXT-cXwd7UW2qtrnkCXM05YAGSQ6
# 3    ftatfYwW7U2-sGlBPakr-5YANNT7
# 4    UwM4R4m6EUywuHZupaUUTpYACvjC
# ..                            ...
# 118  jNxYFUpwqkW4ZNFodzhwCJYAMPNi
# 119  -HSgex3d-keTvOed7xmNwpYAKIRR
# 120  reioAKbv30SXFL0HQ2agXJYAKBDc
# 121  tFIFAIiyqEu3fR_o3TvGfpYAFoTw
# 122  IehKXb2I60u1q3cudI3wjZYAIz6u
#
#                                              Task Name  \
# 0    Fully signed URS of Relief Valve and CIP pump ...
# 1       URS of Relief Valve and CIP pump for new scope
# 2                               Pre-bidding of Group 4
# 3                              Pre-bidding of Group 3
# 4                               Pre-bidding of Group 2
# ..                                                 ...
# 118                                      Create a Plan
# 119      Fully Signed Design Freeze for Dust Collector
# 120                                 Customize  buckets
# 121                Add additional information to tasks
# 122              Delivery of additional control cables
#
#                            Bucket Name     Progress Priority  \
# 0    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 1    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 2    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 3    PEC2020 - (EA) Process Adaptation  Not started   Medium
# 4    PEC2020 - (EA) Process Adaptation  Not started   Medium
# ..                                 ...          ...      ...
# 118     E54 High Pressure Water Heater  Not started   Medium
# 119                   GC Transport PH2  Not started   Medium
# 120                           FFE RARE  Not started   Medium
# 121                        Van Tilting  Not started   Medium
# 122  PEC2020 - PE Panel cooling system    Completed   Medium
#
#                                            Assigned To  \
# 0    Suello,Rosiell,PH-Cagayan de Oro,Engineering,E...
# 1    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# 2    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# 3    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# 4    Tion,Kurlstein Jmaes,PH-Cagayan de Oro,Enginee...
# ..                                                 ...
# 118                                                NaN
# 119  Suello,Rosiell,PH-Cagayan de Oro,Engineering,E...
# 120                                                NaN
# 121                                                NaN
# 122  Pacatan,Arnold,PH-Cagayan de Oro,Engineering,E...
#
#                                             Created By Created Date  \
# 0    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 1    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 2    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 3    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 4    Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# ..                                                 ...          ...
# 118  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 119  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 120  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 121  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
# 122  Cabilogan,Khryssmae Rose,PH-Cagayan de Oro,Eng...   07/02/2024
#
#     Start date    Due date Is Recurring   Late Completed Date  \
# 0          NaN  07/19/2024        False  False            NaN
# 1          NaN  07/12/2024        False  False            NaN
# 2          NaN  02/14/2025        False  False            NaN
# 3          NaN  08/30/2024        False  False            NaN
# 4          NaN  07/05/2024        False  False            NaN
# ..         ...         ...          ...    ...            ...
# 118        NaN  06/26/2024        False   True            NaN
# 119        NaN  07/12/2024        False  False            NaN
# 120        NaN  07/02/2024        False   True            NaN
# 121        NaN  07/11/2024        False  False            NaN
# 122        NaN  05/30/2025        False  False     07/02/2024
#
#                                           Completed By  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122  Pacatan,Arnold,PH-Cagayan de Oro,Engineering,E...
#
#     Completed Checklist Items  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 118                       NaN
# 119                       NaN
# 120                       NaN
# 121                       0/7
# 122                       NaN
#
#                                        Checklist Items      Labels  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 118                                                NaN         NaN
# 119                                                NaN         NaN
# 120                                                NaN  Pink;Green
# 121  Add duration;Add attachments;Add labels;Add ef...         NaN
# 122                                                NaN         NaN
#
#                                            Description
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 118       Create a plan using the simple plan template
# 119           Assign tasks to yourself or team members
# 120  Edit the names of buckets in the project to fi...
# 121                                                NaN
# 122                                                NaN
#
# [123 rows x 18 columns]
